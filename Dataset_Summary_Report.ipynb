# %% [markdown]
# <a href="https://colab.research.google.com/github/jashwanthd19/IDRA-Assignments/blob/main/Dataset_Summary_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("Day7_Student_Dataset.csv")

print("FIRST 5 ROWS")
print(df.head())

print("\nLAST 5 ROWS")
print(df.tail())

print("\nRANDOM 5 ROWS")
print(df.sample(5))

print("\nSHAPE")
print(df.shape)

print("\nCOLUMNS")
print(df.columns)

print("\nINDEX")
print(df.index)

print("\nDATA TYPES")
print(df.dtypes)

print("\nDATASET INFORMATION")
df.info()

print("\nDESCRIPTIVE STATISTICS")
print(df.describe())

print("\nMISSING VALUES")
print(df.isnull().sum())

print("\nNUMBER OF ROWS:", df.shape[0])
print("NUMBER OF COLUMNS:", df.shape[1])

print("\nFEATURES")
for column in df.columns:
    print(column)

print("\nBASIC OBSERVATIONS")
print("The dataset has", df.shape[0], "rows and", df.shape[1], "columns.")
print("The features are:", list(df.columns))

print("\nDATA TYPES OF FEATURES")
print(df.dtypes)

print("\nMISSING VALUES IN EACH COLUMN")
print(df.isnull().sum())

total_missing = df.isnull().sum().sum()

print("\nTOTAL MISSING VALUES:", total_missing)

if total_missing == 0:
    print("There are no missing values in the dataset.")
else:
    print("There are missing values in the dataset.")
# Out:
# FIRST 5 ROWS
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow
#
# LAST 5 ROWS
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# 22        1023   Nikhil Sood   22                AI   78.0
# 23        1024   Maryam Khan   20  Computer Science   85.0
# 24        1025  Reyansh Jain   21      Data Science   80.0
#
# ...
