# %% [markdown]
# <a href="https://colab.research.google.com/github/jashwanthd19/IDRA-Assignments/blob/main/Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os

FILE_NAME = "expenses.csv"

def initialize_file():
    if not os.path.exists(FILE_NAME):
        with open(FILE_NAME, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Date", "Category", "Amount", "Note"])

def add_expense():
    date = input("Enter Date (YYYY-MM-DD): ")
    category = input("Enter Category: ")

    try:
        amount = float(input("Enter Amount: "))
        if amount < 0:
            print("Amount cannot be negative!")
            return
    except ValueError:
        print("Invalid amount! Please enter a numeric value.")
        return

    note = input("Enter Note (optional): ")

    with open(FILE_NAME, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([date, category, amount, note])

    print("Expense added successfully!")

def view_expenses():
    total = 0

    with open(FILE_NAME, "r", newline="") as file:
        reader = csv.reader(file)
        next(reader)

        print("\n--------------------- Expense Records ---------------------")
        print("{:<15}{:<15}{:<12}{}".format("Date", "Category", "Amount", "Note"))
        print("-" * 60)

        found = False

        for row in reader:
            found = True
            print("{:<15}{:<15}{:<12}{}".format(row[0], row[1], row[2], row[3]))
            total += float(row[2])

        if not found:
            print("No expenses found.")

    print("-" * 60)
    print(f"Total Expense = {total:.2f}")

def category_summary():
    summary = {}

    with open(FILE_NAME, "r", newline="") as file:
        reader = csv.reader(file)
        next(reader)

        for row in reader:
            category = row[1]
            amount = float(row[2])

            if category in summary:
                summary[category] += amount
            else:
                summary[category] = amount

    if len(summary) == 0:
        print("No expenses found.")
        return

    print("\n----------- Category-wise Spending -----------")
    print("{:<20}{}".format("Category", "Total Amount"))
    print("-" * 35)

    for category, amount in summary.items():
        print("{:<20}{:.2f}".format(category, amount))

def menu():
    initialize_file()

    while True:
        print("\n========== Expense Tracker ==========")
        print("1. Add Expense")
        print("2. View All Expenses")
        print("3. Category-wise Summary")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_expense()
        elif choice == "2":
            view_expenses()
        elif choice == "3":
            category_summary()
        elif choice == "4":
            print("Thank you for using Expense Tracker!")
            break
        else:
            print("Invalid choice! Please enter a number between 1 and 4.")

menu()
# Out:
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View All Expenses
# 3. Category-wise Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (YYYY-MM-DD): 2020-10-19
# Enter Category: Food
# Enter Amount: 1000
# Enter Note (optional): BreakFast
# Expense added successfully!
#
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View All Expenses
# 3. Category-wise Summary
# 4. Exit
# Enter your choice: 2
#
# --------------------- Expense Records ---------------------
# Date           Category       Amount      Note
# ------------------------------------------------------------
# 2020-10-19     Food           1000.0      BreakFast
# ------------------------------------------------------------
# Total Expense = 1000.00
#
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View All Expenses
# 3. Category-wise Summary
# 4. Exit
# Enter your choice: 3
#
# ----------- Category-wise Spending -----------
# Category            Total Amount
# ...
