# %% [markdown]
# <a href="https://colab.research.google.com/github/jashwanthd19/IDRA-Assignments/blob/main/Number_Guessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("---Number Guessing Number---")

lower=int(input("Enter lower number:"))
upper=int(input("Enter upper number:"))

secret_no=random.randint(lower,upper)

attempts=10

print(f"\nI have chosen a number between {lower} and {upper}.")
print(f"You have {attempts} attempts to guess it.\n")

for i in range(1,attempts+1):
  guess=int(input(f"Attempt:{i}, Enter your guess:"))

  if guess==secret_no:
    print(f"\nCongratulations the correct number is:{secret_no}.")
    print(f"You guessed it in {i} attempts.")
    break
  elif guess<secret_no:
    print("Too low,Try Again!\n")
  else:
    print("Too high,Try Again!\n")

else:
  print(f"\nSorry! You have reached your attempts limit.")
  print(f"The correct number was {secret_no}.")
  print("Good luck next time!")
# Out:
# ---Number Guessing Number---
# Enter lower number:10
# Enter upper number:50
#
# I have chosen a number between 10 and 50.
# You have 10 attempts to guess it.
#
# Attempt:1, Enter your guess:30
#
# Congratulations the correct number is:30.
# You guessed it in 1 attempts.
