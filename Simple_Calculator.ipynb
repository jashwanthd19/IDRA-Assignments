# %% [markdown]
# <a href="https://colab.research.google.com/github/jashwanthd19/IDRA-Assignments/blob/main/Simple_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=float(input("Enter first number:"))
num2=float(input("Enter Second number:"))

Addition=num1+num2
Subtraction=num1-num2
Multiplication=num1 * num2
Division=num1/num2
Floor=num1 // num2
Modulus=num1%num2
Exp=num1 ** num2

print(f"Addition: {Addition}")
print(f"Subtraction :{Subtraction}")
print(f"Multiplication :{Multiplication}")
print(f"Division :{Division}")
print(f"Floor Division :{Floor}")
print(f"Modulus :{Modulus}")
print(f"Exponentiation :{Exp}")
# Out:
# Enter first number:1
# Enter Second number:2
# Addition: 3.0
# Subtraction :-1.0
# Multiplication :2.0
# Division :0.5
# Floor Division :0.0
# Modulus :1.0
# Exponentiation :1.0
